# %%
import pandas as pd

# %%
data = pd.read_csv("/content/Cardiovascular_Disease_Dataset.csv")

# %%
data.head()
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
#
#    fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1           147              0      5.3
# 1                  0                1           115              0      3.7
# 2                  0                0           202              1      5.0
# 3                  1                1           153              0      3.2
# 4                  0                2           136              0      5.3
#
#    slope  noofmajorvessels  target
# 0      3                 3       1
# 1      1                 1       0
# ...

# %%
data.shape
# Out:
# (1000, 14)

# %%
data.tail()
# Out:
#      patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 995    9949544   48       1          2        139              349
# 996    9953423   47       1          3        143              258
# 997    9965859   69       1          0        156              434
# 998    9988507   45       1          1        186              417
# 999    9990855   25       1          0        158              270
#
#      fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 995                  0                2           183              1      5.6
# 996                  1                1            98              1      5.7
# 997                  1                0           196              0      1.4
# 998                  0                1           117              1      5.9
# 999                  0                0           143              1      4.7
#
#      slope  noofmajorvessels  target
# 995      2                 2       1
# ...

# %%
data.dtypes
# Out:
# patientid              int64
# age                    int64
# gender                 int64
# chestpain              int64
# restingBP              int64
# serumcholestrol        int64
# fastingbloodsugar      int64
# restingrelectro        int64
# maxheartrate           int64
# exerciseangia          int64
# oldpeak              float64
# slope                  int64
# noofmajorvessels       int64
# target                 int64
# dtype: object

# %%
data.isna().sum()
# Out:
# patientid            0
# age                  0
# gender               0
# chestpain            0
# restingBP            0
# serumcholestrol      0
# fastingbloodsugar    0
# restingrelectro      0
# maxheartrate         0
# exerciseangia        0
# oldpeak              0
# slope                0
# noofmajorvessels     0
# target               0
# dtype: int64

# %%
data.corr()
# Out:
#                    patientid       age    gender  chestpain  restingBP  \
# patientid           1.000000  0.004978 -0.031263  -0.009679  -0.020926
# age                 0.004978  1.000000 -0.024717   0.037731  -0.016126
# gender             -0.031263 -0.024717  1.000000   0.035402  -0.069727
# chestpain          -0.009679  0.037731  0.035402   1.000000   0.222267
# restingBP          -0.020926 -0.016126 -0.069727   0.222267   1.000000
# serumcholestrol     0.053464  0.035439 -0.120759   0.174731   0.126523
# fastingbloodsugar   0.022331  0.049732  0.023560   0.232059   0.192063
# restingrelectro    -0.003667  0.067736 -0.046634   0.256316   0.219887
# maxheartrate       -0.036486 -0.040092  0.064606   0.114496   0.095569
# exerciseangia       0.014338 -0.037581 -0.051746  -0.027376  -0.046545
# oldpeak            -0.013825 -0.026020  0.331457   0.101345  -0.004225
# slope              -0.010128 -0.015334 -0.051957   0.472731   0.376711
# ...

# %%
x = data.iloc[:,1:-1]
y = data["target"]

# %%
x
# Out:
#      age  gender  chestpain  restingBP  serumcholestrol  fastingbloodsugar  \
# 0     53       1          2        171                0                  0
# 1     40       1          0         94              229                  0
# 2     49       1          2        133              142                  0
# 3     43       1          0        138              295                  1
# 4     31       1          1        199                0                  0
# ..   ...     ...        ...        ...              ...                ...
# 995   48       1          2        139              349                  0
# 996   47       1          3        143              258                  1
# 997   69       1          0        156              434                  1
# 998   45       1          1        186              417                  0
# 999   25       1          0        158              270                  0
#
#      restingrelectro  maxheartrate  exerciseangia  oldpeak  slope  \
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 995    1
# 996    0
# 997    1
# 998    1
# 999    0
# Name: target, Length: 1000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
xtrain
# Out:
#      age  gender  chestpain  restingBP  serumcholestrol  fastingbloodsugar  \
# 29    49       0          1        192              521                  0
# 535   57       1          0        130              318                  0
# 695   62       0          0        187              314                  1
# 557   58       1          0        108              133                  0
# 836   42       1          0        152              348                  0
# ..   ...     ...        ...        ...              ...                ...
# 106   70       1          0        155              203                  1
# 270   56       0          0        139              221                  0
# 860   44       0          3        200              465                  0
# 435   64       1          0        198              137                  0
# 102   80       1          1        130              342                  0
#
#      restingrelectro  maxheartrate  exerciseangia  oldpeak  slope  \
# ...

# %%
xtest
# Out:
#      age  gender  chestpain  restingBP  serumcholestrol  fastingbloodsugar  \
# 521   44       1          0        147              487                  0
# 737   29       1          0        152              138                  0
# 740   72       0          1        156              411                  0
# 660   67       1          0        165              234                  0
# 411   64       0          2         97                0                  0
# ..   ...     ...        ...        ...              ...                ...
# 408   52       1          2        132              287                  0
# 332   21       0          0        139              213                  0
# 208   36       1          2        135              342                  0
# 613   29       0          1        193              226                  0
# 78    63       0          2        131               87                  0
#
#      restingrelectro  maxheartrate  exerciseangia  oldpeak  slope  \
# ...

# %%
ytrain
# Out:
# 29     1
# 535    0
# 695    1
# 557    0
# 836    1
#       ..
# 106    1
# 270    0
# 860    0
# 435    0
# 102    0
# Name: target, Length: 800, dtype: int64

# %%
ytest
# Out:
# 521    1
# 737    0
# 740    0
# 660    0
# 411    1
#       ..
# 408    1
# 332    0
# 208    0
# 613    1
# 78     1
# Name: target, Length: 200, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
xtrain_scaled = scaler.fit_transform(xtrain)
xtest_scaled = scaler.transform(xtest)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_classifier = RandomForestClassifier(random_state = 42)
rf_classifier.fit(xtrain_scaled, ytrain)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred1 = rf_classifier.predict(xtest_scaled)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, r2_score
from sklearn.metrics import roc_auc_score, average_precision_score

# %%
print("f1_score : ",f1_score(ytest, y_pred1))
print("roc_auc_score : ",roc_auc_score(ytest, y_pred1))
print("average_precision_score : ",average_precision_score(ytest, y_pred1))
print("precision_score : ",precision_score(ytest, y_pred1))
print("r2_score : ",r2_score(ytest, y_pred1))
print("recall_score : ",recall_score(ytest, y_pred1))
print("accuracy_score : ",accuracy_score(ytest, y_pred1))
# Out:
# f1_score :  0.9915254237288135
# roc_auc_score :  0.9879518072289157
# average_precision_score :  0.9831932773109243
# precision_score :  0.9831932773109243
# r2_score :  0.9588095973638142
# recall_score :  1.0
# accuracy_score :  0.99

# %%
print(classification_report(ytest, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        83
#            1       0.98      1.00      0.99       117
#
#     accuracy                           0.99       200
#    macro avg       0.99      0.99      0.99       200
# weighted avg       0.99      0.99      0.99       200

# %% [markdown]
# **GRADIO INTERFACE**

# %%
pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 24.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 9.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.1/318.1 kB 31.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 53.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 8.5 MB/s eta 0:00:00
# ...

# %%
import gradio as gr

# %%
# Define the model function
def predict_cardiovascular_disease(age, gender, chestpain, restingBP, serumcholestrol, fastingbloodsugar, restingrelectro, maxheartrate, exerciseangia, oldpeak, slope, noofmajorvessels):
    input_features = [[age, gender, chestpain, restingBP, serumcholestrol, fastingbloodsugar, restingrelectro, maxheartrate, exerciseangia, oldpeak, slope, noofmajorvessels]]
    input_features_scaled = scaler.transform(input_features)
    prediction = rf_classifier.predict(input_features_scaled)
    return "Positive" if prediction[0] == 1 else "Negative"

# %%
# Create the Gradio interface
interface = gr.Interface(
    fn=predict_cardiovascular_disease,
    inputs=["number", "number", "number", "number", "number", "number", "number", "number", "number", "number", "number", "number"],
    outputs="text",
    title="Cardiovascular Disease Prediction",
    description="Predict whether a patient has cardiovascular disease.",
    article="Enter the patient's information to predict the likelihood of cardiovascular disease."
)

# %%
# Run the interface
interface.launch(debug = True)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://7bf9d44f7ef4a1824b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://7bf9d44f7ef4a1824b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://7bf9d44f7ef4a1824b.gradio.live

# %% [markdown]
# **Auto ML - H2O**

# %%
# !pip install h2o
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.3/265.3 MB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for h2o: filename=h2o-3.46.0.3-py2.py3-none-any.whl size=265365897 sha256=37e4c4a9b11a7a623f5c78bef76aaecc5096a3e67b950689ae7ab42d50402bf4
#   Stored in directory: /root/.cache/pip/wheels/c4/63/41/baa115b5255e1db3e2383bce4e2e6181746aac0b42264c242f
# Successfully built h2o
# ...

# %%
import h2o
from h2o.automl import H2OAutoML

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.23" 2024-04-16; OpenJDK Runtime Environment (build 11.0.23+9-post-Ubuntu-1ubuntu122.04.1); OpenJDK 64-Bit Server VM (build 11.0.23+9-post-Ubuntu-1ubuntu122.04.1, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.10/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpxp_e0qab
#   JVM stdout: /tmp/tmpxp_e0qab/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmpxp_e0qab/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------------------------------------------------------------------
# H2O_cluster_uptime:         03 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# ...

# %%
hf = h2o.H2OFrame(data)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
aml = H2OAutoML(max_runtime_secs = 600, seed = 42)

# %%
x = hf.columns[:-1]
y = hf.columns[-1]

# %%
train, test = hf.split_frame(ratios=[0.8], seed= 42)

# %%
aml = H2OAutoML(max_runtime_secs = 600, seed = 42)

# %%
aml.train(x=x, y=y, training_frame = train)
# Out:
# AutoML progress: |
# 03:49:15.69: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# █
# 03:49:19.784: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
#
# 03:49:20.847: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ███
# 03:49:26.162: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# ...

# %%
leaderboard = aml.leaderboard
print(leaderboard)
# Out:
# model_id                                                    rmse        mse        mae      rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_4_AutoML_1_20240401_30752  0.133911  0.0179322  0.0589716  0.0937768                 0.0179322
# StackedEnsemble_AllModels_2_AutoML_1_20240401_30752     0.135464  0.0183505  0.0624556  0.0953816                 0.0183505
# StackedEnsemble_BestOfFamily_3_AutoML_1_20240401_30752  0.135517  0.018365   0.0623078  0.0953731                 0.018365
# StackedEnsemble_BestOfFamily_5_AutoML_1_20240401_30752  0.136543  0.0186441  0.0602379  0.0955609                 0.0186441
# GBM_5_AutoML_1_20240401_30752                           0.137476  0.0188996  0.0574362  0.096381                  0.0188996
# GBM_grid_1_AutoML_1_20240401_30752_model_55             0.138744  0.0192499  0.0537617  0.097252                  0.0192499
# ...

# %%
best_model = aml.leader
print(best_model)
# Out:
# Model Details
# ...
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_BestOfFamily_4_AutoML_1_20240401_30752
#
#
# Model Summary for Stacked Ensemble:
# key                                        value
# -----------------------------------------  ----------------
# Stacking strategy                          cross_validation
# Number of base models (used / total)       3/6
# # GBM base models (used / total)           1/1
# # XGBoost base models (used / total)       1/1
# # DRF base models (used / total)           0/2
# # DeepLearning base models (used / total)  1/1
# # GLM base models (used / total)           0/1
# Metalearner algorithm                      GLM
# Metalearner fold assignment scheme         Random
# Metalearner nfolds                         5
# Metalearner fold_column
# Custom metalearner hyperparameters         None
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.0006617370033684533
# ...

# %%
perf = best_model.model_performance(test_data = test)
print(perf)
# Out:
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on test data. **
#
# MSE: 0.02061465709222406
# RMSE: 0.14357805226504522
# MAE: 0.06322084420288793
# RMSLE: 0.10034556275640648
# Mean Residual Deviance: 0.02061465709222406
# R^2: 0.9148041242893868
# Null degrees of freedom: 211
# Residual degrees of freedom: 208
# Null deviance: 51.32878327192159
# Residual deviance: 4.370307303551501
# AIC: -211.3016866551357

# %%
# !pip install tpot
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.4/87.4 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 47.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 17.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11938 sha256=1174b4bf1e84da14d993a7c5ccf77dd31525eb75f16771c47e00c9518a183163
#   Stored in directory: /root/.cache/pip/wheels/af/f9/87/bf5b3d565c2a007b4dae9d8142dccc85a9f164e517062dd519
# Successfully built stopit
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ...

# %%
from tpot import TPOTClassifier

# %%
tpot = TPOTClassifier(generations = 5, population_size = 50, verbosity = 2, random_state = 42, n_jobs = -1)

# %%
tpot.fit(xtrain, ytrain)
# Out:
# Optimization Progress:   0%|          | 0/300 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: 0.97
#
# Generation 2 - Current best internal CV score: 0.9775
#
# Generation 3 - Current best internal CV score: 0.9775
#
# Generation 4 - Current best internal CV score: 0.9775
#
# Generation 5 - Current best internal CV score: 0.97875
#
# Best pipeline: GradientBoostingClassifier(input_matrix, learning_rate=0.1, max_depth=7, max_features=0.8500000000000001, min_samples_leaf=9, min_samples_split=5, n_estimators=100, subsample=1.0)
# TPOTClassifier(generations=5, n_jobs=-1, population_size=50, random_state=42,
#                verbosity=2)

# %%
y_pred2 = tpot.predict(xtest)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, r2_score
from sklearn.metrics import roc_auc_score, average_precision_score

# %%
print("f1_score : ",f1_score(ytest, y_pred2))
print("roc_auc_score : ",roc_auc_score(ytest, y_pred2))
print("average_precision_score : ",average_precision_score(ytest, y_pred2))
print("precision_score : ",precision_score(ytest, y_pred2))
print("r2_score : ",r2_score(ytest, y_pred2))
print("recall_score : ",recall_score(ytest, y_pred2))
print("accuracy_score : ",accuracy_score(ytest, y_pred2))
# Out:
# f1_score :  0.9743589743589743
# roc_auc_score :  0.9691071980228607
# average_precision_score :  0.9643754109138725
# precision_score :  0.9743589743589743
# r2_score :  0.8764287920914426
# recall_score :  0.9743589743589743
# accuracy_score :  0.97
